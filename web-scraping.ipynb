# %%
pip install selenium beautifulsoup4 webdriver-manager
# Out:
# ...
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service # Handles browser automation
from selenium.webdriver.chrome.options import Options # GUI hide
from webdriver_manager.chrome import ChromeDriverManager # Compatible with the version of chrome installed on your machine (Version control, sets System path)
from bs4 import BeautifulSoup # Extracting data from page source like HTML or XML documents

# %%
options = Options()  # creatig object for options 
options.headless = True
options.disable-gpu = True

# %%
service = Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=service, options=options)

# %%
url ="https://www.youtube.com/@iCodingTamil/videos"
browser.get(url)
time.sleep(5)

# %%
browser.page_source
# Out:
# '<html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en" darker-dark-theme="" darker-dark-theme-deprecate="" system-icons="" typography="" typography-spacing=""><head><script id="js-254315593" nonce="" src="//www.google.com/js/th/-0TfInu9ra9zkah2wyCD78KX7EDwI16Gf6-9m2UuzfU.js" data-loaded="true"></script><script id="js-1124342058" src="//static.doubleclick.net/instream/ad_status.js" nonce="" data-loaded="true"></script><script id="js-1065286052" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js" nonce="" data-loaded="true"></script><script data-original-src="/s/player/37b24ccb/player_ias.vflset/en_US/miniplayer.js" nonce="" src="/s/player/37b24ccb/player_ias.vflset/en_US/miniplayer.js"></script><script data-original-src="/s/player/37b24ccb/player_ias.vflset/en_US/remote.js" nonce="" src="/s/player/37b24ccb/player_ias.vflset/en_US/remote.js"></script><script data-original-src="/s/player/37b24ccb/player_ias.vflset/en_US/offline.js" nonce="" src="/s/pla
# ...

# %%
soup = BeautifulSoup(browser.page_source,'lxml')
titles = soup.find_all('a',{'id':'video-title-link'})
views = soup.find_all('div',{'id':'metadata'})

# %%
datas =[]
for title,view in zip(titles,views):
    datas.append({
        'title':title.text,
         'view':view.find('span').text
        })

print(datas)
# Out:
# [{'title': 'Automate Parsing 1000 PDF Invoices with Python: Extract Data Using PyMuPDF & Pandas | iCoding-Tamil', 'view': '83 views'}, {'title': 'How to Implement a Retry Decorator in Python for Web Scraping', 'view': '69 views'}, {'title': 'Python Automation: Clean Up Your Files and Avoid Duplicate Names | Tamil | iCoding', 'view': '75 views'}, {'title': 'Codewars: Oldest and Youngest Family Members | Tamil | iCoding', 'view': '54 views'}, {'title': 'Codewars : Parse Int from Char | Tamil | iCoding', 'view': '29 views'}, {'title': 'Codewars: Double Char Problem | Tamil | iCoding', 'view': '55 views'}, {'title': '5 Efficient Methods to Remove Duplicates from a Python List | Tamil | iCoding', 'view': '82 views'}, {'title': 'Extract Specific Parts of Strings Using Oracle SQL Regular Expressions | Tamil | iCoding', 'view': '56 views'}, {'title': 'Flatten a Nested List in Python | Tamil | iCoding', 'view': '76 views'}, {'title': 'Delete Duplicate Files Using Python | Step-by-Step Guide',
# ...

# %%
browser.close()
